# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# Pip install method (recommended)
# !pip install ultralytics
from IPython import display
display.clear_output()
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.240 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.5/112.6 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets
# Out:
# /content/datasets

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="XUKQJWmxcWEGarIYF2SV")
project = rf.workspace("almas-mnl25").project("human-animal-nse7t")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 18.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 47.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 78.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to HUMAN-&-ANIMAL-1 in yolov8:: 100%|██████████| 4734/4734 [00:00<00:00, 5763.47it/s]

# %%
# Directory path
dir_path = r"/content/datasets/human/valid/images"
# Get the list of files in the
files_list = os.listdir(dir_path)
# Get the number of files in the directory
num_files = len(files_list)
# Print the number of files
print("The number of files in the directory is:", num_files)
# Directory path
dir_path = r"/content/datasets/human/valid/labels"
# Get the list of files in the directory
files_list = os.listdir(dir_path)
# Get the number of files in the directory
num_files = len(files_list)
# Print the number of files
print("The number of files in the directory is:", num_files)
# Directory path
dir_path = r"/content/datasets/human/train/images"
# Get the list of files in the directory
files_list = os.listdir(dir_path)
# Get the number of files in the directory
num_files = len(files_list)
# Print the number of files
print("The number of files in the directory is:", num_files)
# Directory path
dir_path = r"/content/datasets/human/train/labels"
# Get the list of files in the directory
files_list = os.listdir(dir_path)
# Get the number of files in the directory
num_files = len(files_list)
# Print the number of files
print("The number of files in the directory is:", num_files)
# Out:
# The number of files in the directory is: 197
# The number of files in the directory is: 197
# The number of files in the directory is: 2064
# The number of files in the directory is: 2064

# %%
import os
import shutil
# Source and destination directories
src_dir = r"/content/datasets/human/train/images"
dst_dir = r"/content/datasets/human/valid/images"
# Get a list of all files in the source directory
files = os.listdir(src_dir)
# Sort the files in alphabetical order
files.sort()
# Move the first 700 files to the destination directory
for file in files[:50]:
  src_file = os.path.join(src_dir, file)
  dst_file = os.path.join(dst_dir, file)
  shutil.move(src_file, dst_file)

# %%
# Source and destination directories
src_dir = r'/content/datasets/human/train/labels'
dst_dir = r'/content/datasets/human/valid/labels'
# Get a list of all files in the source directory
files = os.listdir(src_dir)
# Sort the files in alphabetical order
files.sort()
# Move the first 700 files to the destination directory
for file in files[:50]:
  src_file = os.path.join(src_dir, file)
  dst_file = os.path.join(dst_dir, file)
  shutil.move(src_file, dst_file)

# %%
# Directory path
dir_path = r"/content/datasets/human/valid/images"
# Get the list of files in the directory
files_list = os.listdir(dir_path)
# Get the number of files in the directory
num_files = len(files_list)
# Print the number of files
print("The number of files in the directory is:", num_files)
# Directory path
dir_path = r"/content/datasets/human/valid/labels"
# Get the list of files in the directory
files_list = os.listdir(dir_path)
# Get the number of files in the directory
num_files = len(files_list)
# Print the number of files
print("The number of files in the directory is:", num_files)
# Directory path
dir_path = r"/content/datasets/human/train/images"
# Get the list of files in the directory
files_list = os.listdir(dir_path)
# Get the number of files in the directory
num_files = len(files_list)
# Print the number of files
print("The number of files in the directory is:", num_files)
# Directory path
dir_path = r"/content/datasets/human/train/labels"
# Get the list of files in the directory
files_list = os.listdir(dir_path)
# Get the number of files in the directory
num_files = len(files_list)
# Print the number of files
print("The number of files in the directory is:", num_files)
# Out:
# The number of files in the directory is: 247
# The number of files in the directory is: 247
# The number of files in the directory is: 2014
# The number of files in the directory is: 2014

# %%
# %cd {HOME}
# !yolo task=detect mode=train model=yolov8n.pt data=/content/datasets/human/data.yaml epochs=200 imgsz=416 plots=True cache=True batch=32
# Out:
# /content
# ...
# Ultralytics 8.3.240 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO('/content/runs/detect/train/weights/best.pt')

# Export the model to TFLite format

model.export(format='tflite')
# Out:
# Ultralytics 8.3.240 🚀 Python-3.12.12 torch-2.9.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# Model summary (fused): 72 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from '/content/runs/detect/train/weights/best.pt' with input shape (1, 3, 416, 416) BCHW and output shape(s) (1, 6, 3549) (5.9 MB)
# requirements: Ultralytics requirements ['sng4onnx>=1.0.1', 'onnx_graphsurgeon>=0.3.26', 'ai-edge-litert>=1.2.0', 'onnx>=1.12.0,<2.0.0', 'onnx2tf>=1.26.3', 'onnxslim>=0.1.71', 'onnxruntime-gpu'] not found, attempting AutoUpdate...
# Using Python 3.12.12 environment at: /usr
# Resolved 20 packages in 7.59s
# Prepared 11 packages in 6.57s
# Installed 11 packages in 489ms
#  + ai-edge-litert==2.1.0
#  + backports-strenum==1.3.1
#  + colorama==0.4.6
#  + coloredlogs==15.0.1
#  + humanfriendly==10.0
#  + onnx==1.20.0
# ...

# %%
import zipfile
import os
# Set the directory path for the folder you want to download
dir_path = "/content/runs"
# Set the path for the zip file you want to create
zip_path = "/content/human_RUNS.zip"
# Create a zipfile object
zipf = zipfile.ZipFile(zip_path, 'w', zipfile.ZIP_DEFLATED)
# Walk through all the directories and subdirectories in the given path
for root, dirs, files in os.walk(dir_path):
  for file in files:
    # Get the absolute path of the file
    file_path = os.path.join(root, file)
    # Add the file to the zipfile object
    zipf.write(file_path)
# Close the zipfile object
zipf.close()
# Download the zipfile
from google.colab import files
files.download(zip_path)

# %%
import zipfile
import os
# Set the directory path for the folder you want to download
dir_path = "/content/datasets"
# Set the path for the zip file you want to create
zip_path = "/content/human.zip"
# Create a zipfile object
zipf = zipfile.ZipFile(zip_path, 'w', zipfile.ZIP_DEFLATED)
# Walk through all the directories and subdirectories in the given path
for root, dirs, files in os.walk(dir_path):
  for file in files:
    # Get the absolute path of the file
    file_path = os.path.join(root, file)
    # Add the file to the zipfile object
    zipf.write(file_path)
    # Close the zipfile object
zipf.close()
# Download the zipfile
from google.colab import files
files.download(zip_path)
